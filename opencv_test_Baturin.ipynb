# %%
#from IPython.display import display, Image
from IPython.display import display, Image, clear_output
import cv2
from datetime import datetime, timedelta
import time
import numpy as np
#from User_libs import CreateSavePath

display_handle = display(None, display_id=True)

rtsp_url = "rtsp://admin:yDAPqf31@192.168.88.22:554/cam/realmonitor?channel=1&subtype=0"
camera_name = "Dahua_192.168.88.22"

# здесь задать продолжительность работы
delta = timedelta(days=0, seconds=10, minutes=0, hours=0)
stop_datetime = datetime.now() + delta
print('Автозапись изображений в файлы до ', stop_datetime)

#генератор пути к папке, в которую будут сохраняться данные
#SavePath = CreateSavePath(__file__, LAN_Path='\\\\MetroBulk\\Public\\EXP_DATA')
#SavePath = '\\\\MetroBulk\\Public\\!Programs\\!Metrologia_git\\OpenCV'
SavePath = 'C:\\Temp\\'

cv2.namedWindow(camera_name, )

while datetime.now() < stop_datetime:
    
    current_datetime = datetime.now()
    cap = cv2.VideoCapture(rtsp_url, )

    if not cap.isOpened():
        print("Error: Could not open camera.")
        break
    
    ret, frame = cap.read()
    frame = frame[230:930, 450:1090]

    #2560 1440
    # y_len, x_len = np.size(frame, axis=0), np.size(frame, axis=1)
    # y_cen, x_cen = int(y_len/2-1), int(x_len/2-1)
    # cs = [640, 480]

    #Код для вывода кадра прямо в Jupyter вместо отдельного окна:
    #_, en_img = cv2.imencode('.jpg', frame)
    #display(Image(data=en_img))
    
    if not ret:
        print("Error: Could not read frame.")
        break

    #для вывода в поле ноутбука
    #_, en_img = cv2.imencode('.jpg', frame)
    #display_handle.update(Image(data=en_img.tobytes()))
    
    f_time = current_datetime.strftime("%d-%B-%Y_%H-%M-%S")
    fname = SavePath + "DAHUA_" + f_time + ".jpg"
    # можно изменить расширение, если нужен другой формат файла
    cv2.imwrite(fname, frame)
    print('Записан файл: ', fname)

    cv2.imshow(camera_name, frame)
    #cv2.resizeWindow(camera_name, 640, 480)
    cv2.waitKey(25)
    cap.release()

    time.sleep(3)  # установить здесь период записи файлов в секундах

cv2.destroyAllWindows()
# Out:
# None
# Автозапись изображений в файлы до  2025-12-23 15:41:21.542658
# Записан файл:  C:\Temp\DAHUA_23-December-2025_15-41-11.jpg
# Записан файл:  C:\Temp\DAHUA_23-December-2025_15-41-15.jpg
# Записан файл:  C:\Temp\DAHUA_23-December-2025_15-41-20.jpg

# %%
y_len = np.size(frame, axis=0)
x_len = np.size(frame, axis=1)

print(x_len, y_len)
# Out:
# 2560 1440
